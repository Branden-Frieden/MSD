# %% [markdown]
# Branden Frieden
# u1038942
# 5/18/2023
# CS6017
# HW# 2

# %% [markdown]
# null hypothosis: A and B is equal

# %%
import math
pHat = (500+550)/(1000+1000)

z = ((500/1000) - (550/1000))/( math.sqrt(pHat * (1-pHat) * ((1/1000) + (1/1000))))
print("Z = ", z)
# Out:
# Z =  -2.238868314198227

# %%
import scipy.stats
p = scipy.stats.norm.sf(abs(z))
print("P = ", p)
# Out:
# P =  0.012582242850159199

# %% [markdown]
# we can conclude that there is only a 1.2% chance that these 2 adverts are actually the same, assuming a significance value of .05, these 2 advertisements are not equivelent in terms of clicks.

# %% [markdown]
# Part 2

# %%
import pandas as pd

#task 1
re1 = pd.read_csv("realEstate1.csv")
re2 = pd.read_csv("realEstate2.csv")
realEstate = pd.concat([re1, re2])

# %%
#task2

display(realEstate)
# Out:
#       ListNo                  Access  AdditInfo  Acres             ListAgt
# 0    1397571                Concrete        NaN   0.29          Liz Slager  \
# 1    1394021                 Asphalt        NaN   0.01      Angela Carlson
# 2    1393604                     NaN        NaN   0.11     Rachel Kitterer
# 3    1393602                Concrete        NaN   0.14     Rachel Kitterer
# 4    1393829                 Asphalt        NaN   0.01  T. Carter Maudsley
# ..       ...                     ...        ...    ...                 ...
# 143  1277128                Concrete        NaN   0.28          Liz Slager
# 144  1265274                Concrete        NaN   0.01    PATRICK WISCOMBE
# 145  1241781                Concrete        NaN   0.00     Jacqui Johnston
# 146  1238399                     NaN        NaN   0.07        Grady Kohler
# 147  1222911  Common Drive; Concrete        NaN   0.01       Jennifer Beck
#
#                               AirType
# 0               Central Air; Electric  \
# 1               Central Air; Electric
# 2               Central Air; Electric
# 3               Central Air; Electric
# 4               Central Air; Electric
# ..                                ...
# 143             Central Air; Electric
# 144             Central Air; Electric
# 145             Central Air; Electric
# 146             Central Air; Electric
# 147  Central Air; Electric; Heat Pump
#
#                                              Amenities  Area  BackDim
# 0    See Remarks; Cable Tv Available; Cable Tv Wire...   101      0.0  \
# 1            Cable Tv Available; Electric Dryer Hookup   101      0.0
# 2                Cable Tv Wired; Electric Dryer Hookup   101      0.0
# 3                Cable Tv Wired; Electric Dryer Hookup   101      0.0
# 4                                       Cable Tv Wired   101      0.0
# ..                                                 ...   ...      ...
# 143  Cable Tv Wired; Electric Dryer Hookup; Exercis...   101      0.0
# 144  Electric Dryer Hookup; Exercise Room; Gas Drye...   101      0.0
# 145                       Exercise Room; Swimming Pool   101      0.0
# 146          Cable Tv Available; Electric Dryer Hookup   101      0.0
# 147  Cable Tv Wired; Clubhouse; Electric Dryer Hook...   101      0.0
#
#                                Basemnt  ...  WinEvp1 WinEvp2 WinEvp3 WinEvp4
# 0    Daylight; Entrance; Full; Walkout  ...        0       0       0       0  \
# 1                     None/Crawl Space  ...        0       0       0       0
# 2                                 Full  ...        0       0       0       0
# 3                                 Full  ...        0       0       0       0
# 4                     None/Crawl Space  ...        0       0       0       0
# ..                                 ...  ...      ...     ...     ...     ...
# 143                   Partial; Walkout  ...        0       0       0       0
# 144                   None/Crawl Space  ...        0       0       0       0
# 145                   None/Crawl Space  ...        0       0       0       0
# 146                   None/Crawl Space  ...        0       0       0       0
# 147                   None/Crawl Space  ...        0       0       0       0
#
#                           Window    WithDrDt YearBlt    Zip Zoning     LastMod
# 0                         Blinds  00/00/0000    1998  84103    NaN  08/29/2016
# 1    Blinds; Plantation Shutters  00/00/0000    1965  84103    RES  08/22/2016
# 2    Blinds; Plantation Shutters  00/00/0000    1940  84103    NaN  08/29/2016
# 3                         Blinds  00/00/0000    1940  84103    NaN  08/29/2016
# 4                            NaN  00/00/0000    1969  84103    NaN  08/18/2016
# ..                           ...         ...     ...    ...    ...         ...
# 143                 Blinds; Full  00/00/0000    1978  84103    RES  10/06/2015
# 144                 Full; Shades  00/00/0000    1979  84103    NaN  05/24/2016
# 145                    Draperies  00/00/0000    1976  84103  CONDO  10/29/2015
# 146                          NaN  00/00/0000    1886  84103    NaN  09/11/2015
# 147                 Blinds; Full  00/00/0000    1981  84103    R-1  10/01/2015
#
# [348 rows x 206 columns]

# %%
realEstate = realEstate[realEstate.LstPrice > 200000] 
realEstate = realEstate[realEstate.LstPrice < 1000000]
display(realEstate)
# Out:
#       ListNo                  Access  AdditInfo  Acres           ListAgt
# 0    1397571                Concrete        NaN   0.29        Liz Slager  \
# 1    1394021                 Asphalt        NaN   0.01    Angela Carlson
# 2    1393604                     NaN        NaN   0.11   Rachel Kitterer
# 3    1393602                Concrete        NaN   0.14   Rachel Kitterer
# 5    1393370                 Asphalt        NaN   0.01      Larry Cragun
# ..       ...                     ...        ...    ...               ...
# 143  1277128                Concrete        NaN   0.28        Liz Slager
# 144  1265274                Concrete        NaN   0.01  PATRICK WISCOMBE
# 145  1241781                Concrete        NaN   0.00   Jacqui Johnston
# 146  1238399                     NaN        NaN   0.07      Grady Kohler
# 147  1222911  Common Drive; Concrete        NaN   0.01     Jennifer Beck
#
#                               AirType
# 0               Central Air; Electric  \
# 1               Central Air; Electric
# 2               Central Air; Electric
# 3               Central Air; Electric
# 5               Central Air; Electric
# ..                                ...
# 143             Central Air; Electric
# 144             Central Air; Electric
# 145             Central Air; Electric
# 146             Central Air; Electric
# 147  Central Air; Electric; Heat Pump
#
#                                              Amenities  Area  BackDim
# 0    See Remarks; Cable Tv Available; Cable Tv Wire...   101      0.0  \
# 1            Cable Tv Available; Electric Dryer Hookup   101      0.0
# 2                Cable Tv Wired; Electric Dryer Hookup   101      0.0
# 3                Cable Tv Wired; Electric Dryer Hookup   101      0.0
# 5    Cable Tv Wired; Exercise Room; Swimming Pool; ...   101      0.0
# ..                                                 ...   ...      ...
# 143  Cable Tv Wired; Electric Dryer Hookup; Exercis...   101      0.0
# 144  Electric Dryer Hookup; Exercise Room; Gas Drye...   101      0.0
# 145                       Exercise Room; Swimming Pool   101      0.0
# 146          Cable Tv Available; Electric Dryer Hookup   101      0.0
# 147  Cable Tv Wired; Clubhouse; Electric Dryer Hook...   101      0.0
#
#                                Basemnt  ...  WinEvp1 WinEvp2 WinEvp3 WinEvp4
# 0    Daylight; Entrance; Full; Walkout  ...        0       0       0       0  \
# 1                     None/Crawl Space  ...        0       0       0       0
# 2                                 Full  ...        0       0       0       0
# 3                                 Full  ...        0       0       0       0
# 5                     None/Crawl Space  ...        0       0       0       0
# ..                                 ...  ...      ...     ...     ...     ...
# 143                   Partial; Walkout  ...        0       0       0       0
# 144                   None/Crawl Space  ...        0       0       0       0
# 145                   None/Crawl Space  ...        0       0       0       0
# 146                   None/Crawl Space  ...        0       0       0       0
# 147                   None/Crawl Space  ...        0       0       0       0
#
#                           Window    WithDrDt YearBlt    Zip Zoning     LastMod
# 0                         Blinds  00/00/0000    1998  84103    NaN  08/29/2016
# 1    Blinds; Plantation Shutters  00/00/0000    1965  84103    RES  08/22/2016
# 2    Blinds; Plantation Shutters  00/00/0000    1940  84103    NaN  08/29/2016
# 3                         Blinds  00/00/0000    1940  84103    NaN  08/29/2016
# 5                            NaN  00/00/0000    1976  84103    NaN  08/01/2016
# ..                           ...         ...     ...    ...    ...         ...
# 143                 Blinds; Full  00/00/0000    1978  84103    RES  10/06/2015
# 144                 Full; Shades  00/00/0000    1979  84103    NaN  05/24/2016
# 145                    Draperies  00/00/0000    1976  84103  CONDO  10/29/2015
# 146                          NaN  00/00/0000    1886  84103    NaN  09/11/2015
# 147                 Blinds; Full  00/00/0000    1981  84103    R-1  10/01/2015
#
# [260 rows x 206 columns]

# %%
realEstate = realEstate.loc[:,['Acres', 'Deck', 'GaragCap', 'Latitude', 'Longitude', 'LstPrice', 'Patio', 'PkgSpacs', 'PropType', 'SoldPrice', 'Taxes', 'TotBed', 'TotBth', 'TotSqf', 'YearBlt']]
display(realEstate)
# Out:
#      Acres  Deck  GaragCap   Latitude   Longitude  LstPrice  Patio  PkgSpacs
# 0     0.29     1         3  40.779524 -111.893542    725000      1         0  \
# 1     0.01     0         0  40.773243 -111.883291    205000      0         0
# 2     0.11     0         0  40.773972 -111.867470    390000      1         0
# 3     0.14     0         1  40.783009 -111.872100    445000      1         3
# 5     0.01     0         2  40.771693 -111.886951    339000      0         2
# ..     ...   ...       ...        ...         ...       ...    ...       ...
# 143   0.28     1         3  40.782933 -111.851143    995000      0         6
# 144   0.01     0         2  40.770904 -111.886201    349999      2         2
# 145   0.00     0         0  40.773843 -111.891911    249900      0         0
# 146   0.07     0         1  40.772835 -111.854867    330000      0         0
# 147   0.01     1         2  40.771980 -111.885262    385000      1         0
#
#           PropType  SoldPrice  Taxes  TotBed  TotBth TotSqf  YearBlt
# 0    Single Family     752000   7244     4.0     5.0  5,415     1998
# 1            Condo     205000   1431     2.0     1.0    924     1965
# 2    Single Family     390000   1816     3.0     1.0  1,702     1940
# 3    Single Family     443000   3260     3.0     2.0  1,756     1940
# 5            Condo     334000   2141     3.0     2.0  1,368     1976
# ..             ...        ...    ...     ...     ...    ...      ...
# 143  Single Family     949000   6658     6.0     4.0  5,740     1978
# 144          Condo     340000   1877     2.0     2.0  1,473     1979
# 145          Condo     231000   2812     2.0     2.0  1,385     1976
# 146  Single Family     310000   2079     5.0     3.0  2,094     1886
# 147          Condo     370000   3644     2.0     2.0  2,028     1981
#
# [260 rows x 15 columns]

# %%
realEstate.dtypes
# Out:
# Acres        float64
# Deck           int64
# GaragCap       int64
# Latitude     float64
# Longitude    float64
# LstPrice       int64
# Patio          int64
# PkgSpacs       int64
# PropType      object
# SoldPrice      int64
# Taxes          int64
# TotBed       float64
# TotBth       float64
# TotSqf        object
# YearBlt        int64
# dtype: object

# %%
realEstate['TotSqf'] = realEstate['TotSqf'].str.replace(',', '').astype(int)

# %%
realEstate.dtypes
# Out:
# Acres        float64
# Deck           int64
# GaragCap       int64
# Latitude     float64
# Longitude    float64
# LstPrice       int64
# Patio          int64
# PkgSpacs       int64
# PropType      object
# SoldPrice      int64
# Taxes          int64
# TotBed       float64
# TotBth       float64
# TotSqf         int64
# YearBlt        int64
# dtype: object

# %%
import numpy as np
realEstate['Prop_Type_SingleFamily'] = np.where(realEstate['PropType'] == 'Single Family', 1, 0)
display(realEstate)
# Out:
#      Acres  Deck  GaragCap   Latitude   Longitude  LstPrice  Patio  PkgSpacs
# 0     0.29     1         3  40.779524 -111.893542    725000      1         0  \
# 1     0.01     0         0  40.773243 -111.883291    205000      0         0
# 2     0.11     0         0  40.773972 -111.867470    390000      1         0
# 3     0.14     0         1  40.783009 -111.872100    445000      1         3
# 5     0.01     0         2  40.771693 -111.886951    339000      0         2
# ..     ...   ...       ...        ...         ...       ...    ...       ...
# 143   0.28     1         3  40.782933 -111.851143    995000      0         6
# 144   0.01     0         2  40.770904 -111.886201    349999      2         2
# 145   0.00     0         0  40.773843 -111.891911    249900      0         0
# 146   0.07     0         1  40.772835 -111.854867    330000      0         0
# 147   0.01     1         2  40.771980 -111.885262    385000      1         0
#
#           PropType  SoldPrice  Taxes  TotBed  TotBth  TotSqf  YearBlt
# 0    Single Family     752000   7244     4.0     5.0    5415     1998  \
# 1            Condo     205000   1431     2.0     1.0     924     1965
# 2    Single Family     390000   1816     3.0     1.0    1702     1940
# 3    Single Family     443000   3260     3.0     2.0    1756     1940
# 5            Condo     334000   2141     3.0     2.0    1368     1976
# ..             ...        ...    ...     ...     ...     ...      ...
# 143  Single Family     949000   6658     6.0     4.0    5740     1978
# 144          Condo     340000   1877     2.0     2.0    1473     1979
# 145          Condo     231000   2812     2.0     2.0    1385     1976
# 146  Single Family     310000   2079     5.0     3.0    2094     1886
# 147          Condo     370000   3644     2.0     2.0    2028     1981
#
#      Prop_Type_SingleFamily
# 0                         1
# 1                         0
# 2                         1
# 3                         1
# 5                         0
# ..                      ...
# 143                       1
# 144                       0
# 145                       0
# 146                       1
# 147                       0
#
# [260 rows x 16 columns]

# %%
realEstate = realEstate[realEstate.Longitude > -113] 
realEstate = realEstate[realEstate.Longitude < -110]

realEstate = realEstate[realEstate.Taxes < 10000]

display(realEstate)
# Out:
#      Acres  Deck  GaragCap   Latitude   Longitude  LstPrice  Patio  PkgSpacs
# 0     0.29     1         3  40.779524 -111.893542    725000      1         0  \
# 1     0.01     0         0  40.773243 -111.883291    205000      0         0
# 2     0.11     0         0  40.773972 -111.867470    390000      1         0
# 3     0.14     0         1  40.783009 -111.872100    445000      1         3
# 5     0.01     0         2  40.771693 -111.886951    339000      0         2
# ..     ...   ...       ...        ...         ...       ...    ...       ...
# 143   0.28     1         3  40.782933 -111.851143    995000      0         6
# 144   0.01     0         2  40.770904 -111.886201    349999      2         2
# 145   0.00     0         0  40.773843 -111.891911    249900      0         0
# 146   0.07     0         1  40.772835 -111.854867    330000      0         0
# 147   0.01     1         2  40.771980 -111.885262    385000      1         0
#
#           PropType  SoldPrice  Taxes  TotBed  TotBth  TotSqf  YearBlt
# 0    Single Family     752000   7244     4.0     5.0    5415     1998  \
# 1            Condo     205000   1431     2.0     1.0     924     1965
# 2    Single Family     390000   1816     3.0     1.0    1702     1940
# 3    Single Family     443000   3260     3.0     2.0    1756     1940
# 5            Condo     334000   2141     3.0     2.0    1368     1976
# ..             ...        ...    ...     ...     ...     ...      ...
# 143  Single Family     949000   6658     6.0     4.0    5740     1978
# 144          Condo     340000   1877     2.0     2.0    1473     1979
# 145          Condo     231000   2812     2.0     2.0    1385     1976
# 146  Single Family     310000   2079     5.0     3.0    2094     1886
# 147          Condo     370000   3644     2.0     2.0    2028     1981
#
#      Prop_Type_SingleFamily
# 0                         1
# 1                         0
# 2                         1
# 3                         1
# 5                         0
# ..                      ...
# 143                       1
# 144                       0
# 145                       0
# 146                       1
# 147                       0
#
# [257 rows x 16 columns]

# %% [markdown]
# my dataset has 257 different items, each has 16 variables describing them. These values all seem to be resonable.

# %%
realEstate['PropType'].value_counts().plot.bar(y='count', figsize=(5,5))
# Out:
# <Axes: xlabel='PropType'>

# %%
realEstate.corr(method='pearson', min_periods=1, numeric_only=True)
# Out:
#                            Acres      Deck  GaragCap  Latitude  Longitude
# Acres                   1.000000  0.165732  0.447886  0.568249   0.235933  \
# Deck                    0.165732  1.000000  0.079294  0.184221   0.019710
# GaragCap                0.447886  0.079294  1.000000  0.323426   0.079707
# Latitude                0.568249  0.184221  0.323426  1.000000  -0.252985
# Longitude               0.235933  0.019710  0.079707 -0.252985   1.000000
# LstPrice                0.716560  0.165510  0.636116  0.371438   0.375739
# Patio                   0.005157  0.753466 -0.048481 -0.026625   0.047546
# PkgSpacs                0.178064  0.027597 -0.026026  0.169701   0.044034
# SoldPrice               0.709380  0.161274  0.626073  0.374229   0.378518
# Taxes                   0.678446  0.119304  0.629634  0.344140   0.345215
# TotBed                  0.588819  0.117856  0.352746  0.292322   0.315474
# TotBth                  0.504789  0.107399  0.597674  0.299270   0.141285
# TotSqf                  0.738043  0.173308  0.570661  0.415019   0.275745
# YearBlt                 0.110440  0.130219  0.470059  0.333459  -0.231580
# Prop_Type_SingleFamily  0.550447  0.067675  0.013056  0.293326   0.332640
#
#                         LstPrice     Patio  PkgSpacs  SoldPrice     Taxes
# Acres                   0.716560  0.005157  0.178064   0.709380  0.678446  \
# Deck                    0.165510  0.753466  0.027597   0.161274  0.119304
# GaragCap                0.636116 -0.048481 -0.026026   0.626073  0.629634
# Latitude                0.371438 -0.026625  0.169701   0.374229  0.344140
# Longitude               0.375739  0.047546  0.044034   0.378518  0.345215
# LstPrice                1.000000 -0.017352  0.164530   0.994978  0.878184
# Patio                  -0.017352  1.000000 -0.033298  -0.013058 -0.038108
# PkgSpacs                0.164530 -0.033298  1.000000   0.149729  0.094513
# SoldPrice               0.994978 -0.013058  0.149729   1.000000  0.873635
# Taxes                   0.878184 -0.038108  0.094513   0.873635  1.000000
# TotBed                  0.649052  0.012585  0.204235   0.644520  0.547986
# TotBth                  0.738358 -0.057990  0.138750   0.725855  0.726250
# TotSqf                  0.866691 -0.017008  0.188713   0.856134  0.814223
# YearBlt                 0.207930 -0.026131 -0.170480   0.202465  0.307737
# Prop_Type_SingleFamily  0.375962  0.078574  0.245102   0.383369  0.240413
#
#                           TotBed    TotBth    TotSqf   YearBlt
# Acres                   0.588819  0.504789  0.738043  0.110440  \
# Deck                    0.117856  0.107399  0.173308  0.130219
# GaragCap                0.352746  0.597674  0.570661  0.470059
# Latitude                0.292322  0.299270  0.415019  0.333459
# Longitude               0.315474  0.141285  0.275745 -0.231580
# LstPrice                0.649052  0.738358  0.866691  0.207930
# Patio                   0.012585 -0.057990 -0.017008 -0.026131
# PkgSpacs                0.204235  0.138750  0.188713 -0.170480
# SoldPrice               0.644520  0.725855  0.856134  0.202465
# Taxes                   0.547986  0.726250  0.814223  0.307737
# TotBed                  1.000000  0.598963  0.723863 -0.055325
# TotBth                  0.598963  1.000000  0.788167  0.310558
# TotSqf                  0.723863  0.788167  1.000000  0.150309
# YearBlt                -0.055325  0.310558  0.150309  1.000000
# Prop_Type_SingleFamily  0.495204  0.171414  0.422695 -0.523346
#
#                         Prop_Type_SingleFamily
# Acres                                 0.550447
# Deck                                  0.067675
# GaragCap                              0.013056
# Latitude                              0.293326
# Longitude                             0.332640
# LstPrice                              0.375962
# Patio                                 0.078574
# PkgSpacs                              0.245102
# SoldPrice                             0.383369
# Taxes                                 0.240413
# TotBed                                0.495204
# TotBth                                0.171414
# TotSqf                                0.422695
# YearBlt                              -0.523346
# Prop_Type_SingleFamily                1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plot = sns.heatmap(realEstate.corr(numeric_only=True), cmap="YlGnBu", annot=False, vmin=-1, vmax=1)
plt.show()

# %%
import plotly.express as px
scatterData = realEstate.loc[:,['Acres', 'LstPrice', 'SoldPrice', 'Taxes', 'TotBed', 'TotBth', 'TotSqf', 'YearBlt']]
fig = px.scatter_matrix(scatterData, dimensions=['Acres', 'LstPrice', 'SoldPrice', 'Taxes', 'TotBed', 'TotBth', 'TotSqf', 'YearBlt'])
fig.update_layout(height=800, width=1200)
fig.show()

# %% [markdown]
# strong correlations:
#
#     soldPrice, LstPrice
#
#
#     taxes, soldPrice
#
#
#     taxes, LstPrice
#
# there are some others that look correlated, but these are by far the strongest 3.

# %% [markdown]
# # Task 4

# %%
img = plt.imread("map.png")

fig, ax = plt.subplots()

plt.imshow(img, extent=[-111.92, -111.83, 40.765,40.795])
plt.scatter(realEstate.Longitude, realEstate.Latitude, c=realEstate.SoldPrice, cmap='viridis')
plt.colorbar()

plt.xlim(-111.92,-111.83)
plt.ylim(40.765,40.795)

plt.show()

# %% [markdown]
# The further North and East you go, the more valuable the houses are, whle the southwest is less valuable on average.

# %% [markdown]
# # Task 5

# %%
import statsmodels.formula.api as sm

price_ols = sm.ols(formula="SoldPrice ~ LstPrice", data=realEstate ).fit()

display(price_ols.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SoldPrice   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 2.520e+04
# Date:                Fri, 09 Jun 2023   Prob (F-statistic):          6.30e-257
# Time:                        13:44:46   Log-Likelihood:                -2893.0
# No. Observations:                 257   AIC:                             5790.
# Df Residuals:                     255   BIC:                             5797.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.267e+04   2999.326      4.225      0.000    6765.496    1.86e+04
# LstPrice       0.9456      0.006    158.743      0.000       0.934       0.957
# ==============================================================================
# Omnibus:                      126.634   Durbin-Watson:                   1.854
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              940.639
# Skew:                          -1.819   Prob(JB):                    5.53e-205
# Kurtosis:                      11.638   Cond. No.                     1.29e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# R2 is .990 which means that the list price describes 99% of the variability of the sold price.

# %%
plt.scatter(realEstate['LstPrice'], realEstate['SoldPrice'], color='red')
xs = np.linspace(200000, 1000000, 100)
plt.plot(xs, .9456 * xs + 12670)

# %% [markdown]
# # Task 6

# %%
all_ols = sm.ols(formula="SoldPrice ~ Acres + Deck + GaragCap + Latitude + Longitude + Patio + PkgSpacs + Taxes + TotBed + TotBth + TotSqf + YearBlt + Prop_Type_SingleFamily", data=realEstate).fit()
all_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SoldPrice   R-squared:                       0.851
# Model:                            OLS   Adj. R-squared:                  0.843
# Method:                 Least Squares   F-statistic:                     106.5
# Date:                Fri, 09 Jun 2023   Prob (F-statistic):           2.20e-92
# Time:                        13:44:46   Log-Likelihood:                -3240.2
# No. Observations:                 257   AIC:                             6508.
# Df Residuals:                     243   BIC:                             6558.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept               1.248e+08    5.3e+07      2.353      0.019    2.03e+07    2.29e+08
# Acres                   2.836e+04   7.18e+04      0.395      0.693   -1.13e+05     1.7e+05
# Deck                    8050.9232   6185.679      1.302      0.194   -4133.468    2.02e+04
# GaragCap                2.366e+04   6894.775      3.432      0.001    1.01e+04    3.72e+04
# Latitude                5.203e+05   1.28e+06      0.407      0.684      -2e+06    3.04e+06
# Longitude               1.306e+06   4.44e+05      2.943      0.004    4.32e+05    2.18e+06
# Patio                  -1944.5611   2221.927     -0.875      0.382   -6321.256    2432.134
# PkgSpacs                1702.3470   3123.070      0.545      0.586   -4449.396    7854.090
# Taxes                     49.8056      5.882      8.467      0.000      38.219      61.392
# TotBed                  7354.8000   5996.139      1.227      0.221   -4456.241    1.92e+04
# TotBth                  6986.8596   8107.701      0.862      0.390   -8983.482     2.3e+04
# TotSqf                    39.7406      9.717      4.090      0.000      20.601      58.881
# YearBlt                   99.9146    227.590      0.439      0.661    -348.386     548.215
# Prop_Type_SingleFamily   4.12e+04   2.05e+04      2.013      0.045     889.745    8.15e+04
# ==============================================================================
# Omnibus:                       23.575   Durbin-Watson:                   1.883
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               38.258
# Skew:                           0.553   Prob(JB):                     4.92e-09
# Kurtosis:                       4.533   Cond. No.                     5.40e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.4e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# the best indicators for the list price are:
# * Taxes
# * TotSqft
# * GarageCap
# * Longitude
#
# the coefficient of TotSqft indicates the increase in the value of the house for each increase in the square footage. So the coefficient of TotSqft means that an increase of one square footage will increase the value of the house $39.74
#
# each garage spot adds around $23660 value to the total value of the house.
#
# longitude and latitude both have and impact on the value of the house. both have large coefficients, so even though the change in the value of the longittude and latitude is small, the change in the value of the house is large.

# %%
lst_ols = sm.ols(formula="SoldPrice ~ LstPrice", data=realEstate).fit()
lst_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SoldPrice   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 2.520e+04
# Date:                Fri, 09 Jun 2023   Prob (F-statistic):          6.30e-257
# Time:                        13:44:46   Log-Likelihood:                -2893.0
# No. Observations:                 257   AIC:                             5790.
# Df Residuals:                     255   BIC:                             5797.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.267e+04   2999.326      4.225      0.000    6765.496    1.86e+04
# LstPrice       0.9456      0.006    158.743      0.000       0.934       0.957
# ==============================================================================
# Omnibus:                      126.634   Durbin-Watson:                   1.854
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              940.639
# Skew:                          -1.819   Prob(JB):                    5.53e-205
# Kurtosis:                      11.638   Cond. No.                     1.29e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Our model has a R^2 value of .851 while the LstPrice model has a R^2 value of .990, so out model is not as good of an indicator as the LstPrice model.

# %% [markdown]
# # Task 7

# %% [markdown]
# The property type is determined by (or at least tied to) the total square footage of the property.

# %%
sns.relplot(x='TotSqf', y='SoldPrice', hue='PropType', data=realEstate, )
plt.show()

# %% [markdown]
# as we can see, the condos are much smaller in TotSqf than the average townhouse or Single Family house.
