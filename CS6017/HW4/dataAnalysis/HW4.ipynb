# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#task 1
dumb = pd.read_csv("dumbKnn.txt")
bucket = pd.read_csv("bucketKnn.txt")
quad = pd.read_csv("quadTreeKnn.txt")
kd = pd.read_csv("kdTreeKnn.txt")

# %%
display(kd)
# Out:
#     dimension   k    n    time
# 0           2  10    0   53448
# 1           3  10    0   72911
# 2           4  10    0  126316
# 3           5  10    0  217900
# 4           6  10    0  295356
# ..        ...  ..  ...     ...
# 65          2  10  100   53041
# 66          2  11  100   49724
# 67          2  12  100   51005
# 68          2  13  100   53415
# 69          2  14  100   55273
#
# [70 rows x 4 columns]

# %%
start = 0
end = 9
print(dumb.iloc[end])
plt.scatter(x = dumb["dimension"].iloc[start:end], y = dumb["time"].iloc[start:end], color = "red")
plt.scatter(x = bucket["dimension"].iloc[start:end], y = bucket["time"].iloc[start:end], color = "blue")
plt.scatter(x = kd["dimension"].iloc[start:end], y = kd["time"].iloc[start:end], color = "black")
plt.legend(["dumb", "bucket", "kd"],)
plt.xlabel("dimensions")
plt.ylabel("Time")
# Out:
# dimension        2
# k               10
# n              100
# time         75338
# Name: 9, dtype: int64
# Text(0, 0.5, 'Time')

# %%
start = 10
end = 59
print(dumb.iloc[end])
plt.scatter(x = dumb["n"].iloc[start:end], y = dumb["time"].iloc[start:end], color = "red")
plt.scatter(x = bucket["n"].iloc[start:end], y = bucket["time"].iloc[start:end], color = "blue")
plt.scatter(x = quad["n"].iloc[start:end], y = quad["time"].iloc[start:end], color = "green")
plt.scatter(x = kd["n"].iloc[start:end], y = kd["time"].iloc[start:end], color = "black")
plt.legend(["dumb", "bucket", "quad", "kd"],)
plt.xlabel("test points")
plt.ylabel("Time")
# Out:
# dimension         2
# k                10
# n               600
# time         450313
# Name: 59, dtype: int64
# Text(0, 0.5, 'Time')

# %%
start = 60
end = 69
print(dumb.iloc[end])
plt.scatter(x = dumb["k"].iloc[start:end], y = dumb["time"].iloc[start:end], color = "red")
plt.scatter(x = bucket["k"].iloc[start:end], y = bucket["time"].iloc[start:end], color = "blue")
plt.scatter(x = quad["k"].iloc[start:end], y = quad["time"].iloc[start:end], color = "green")
plt.scatter(x = kd["k"].iloc[start:end], y = kd["time"].iloc[start:end], color = "black")
plt.legend(["dumb", "bucket", "quad", "kd"],)
plt.xlabel("neighbors")
plt.ylabel("Time")
# Out:
# dimension        2
# k               14
# n              100
# time         84651
# Name: 69, dtype: int64
# Text(0, 0.5, 'Time')

# %%
import statsmodels.formula.api as sm
lst_ols = sm.ols(formula="time ~ dimension + k + n", data=dumb).fit()
lst_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   time   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                     5690.
# Date:                Tue, 27 Jun 2023   Prob (F-statistic):           1.38e-79
# Time:                        13:55:25   Log-Likelihood:                -721.56
# No. Observations:                  70   AIC:                             1451.
# Df Residuals:                      66   BIC:                             1460.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -5.68e+04   8325.316     -6.823      0.000   -7.34e+04   -4.02e+04
# ...

# %%
import statsmodels.formula.api as sm
lst_ols = sm.ols(formula="time ~ dimension + k + n", data=bucket).fit()
lst_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   time   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     2458.
# Date:                Tue, 27 Jun 2023   Prob (F-statistic):           1.25e-67
# Time:                        13:55:25   Log-Likelihood:                -880.22
# No. Observations:                  70   AIC:                             1768.
# Df Residuals:                      66   BIC:                             1777.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -8.166e+04   8.03e+04     -1.017      0.313   -2.42e+05    7.87e+04
# ...

# %%
import statsmodels.formula.api as sm
lst_ols = sm.ols(formula="time ~ dimension + k + n", data=quad).fit()
lst_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   time   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     829.1
# Date:                Tue, 27 Jun 2023   Prob (F-statistic):           5.49e-48
# Time:                        13:55:25   Log-Likelihood:                -738.38
# No. Observations:                  70   AIC:                             1483.
# Df Residuals:                      67   BIC:                             1489.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1714.2041   2057.379     -0.833      0.408   -5820.749    2392.341
# ...

# %%
import statsmodels.formula.api as sm
lst_ols = sm.ols(formula="time ~ dimension + k + n", data=kd).fit()
lst_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   time   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     2895.
# Date:                Tue, 27 Jun 2023   Prob (F-statistic):           5.90e-70
# Time:                        13:55:25   Log-Likelihood:                -743.06
# No. Observations:                  70   AIC:                             1494.
# Df Residuals:                      66   BIC:                             1503.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.783e+05   1.13e+04    -15.710      0.000   -2.01e+05   -1.56e+05
# ...
